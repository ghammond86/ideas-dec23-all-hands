# %%
import os
import sys
sys.path.append('/scratch/ideas-dec23-all-hands/.python')
from run import run_pflotran
from plot import plot_results
os.chdir('/scratch/ideas-dec23-all-hands/carbon_mineralization')

# %%
prefix = 'no_inhibition'

# %%
run_pflotran(prefix)
# Out:
#  Step    200 Time=  9.95417E+00 Dt=  5.00000E-02 [d] conv_reason: 4
#   newton =   4 [     663] linear =     4 [       663] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations = 4 / 4
#   --> SNES Residual: 0.178810E-18 0.178810E-18 0.176679E-18
#   --> max change:  dcmx=   3.0769E-13  dc/dt=   7.1225E-17 [mol/s]
#
# == REACTIVE TRANSPORT ==========================================================
#   0 2r: 1.18E-13 2x: 0.00E+00 2u: 0.00E+00 ir: 7.10E-14 iu: 0.00E+00 rsn:   0
#   1 2r: 4.04E-15 2x: 3.77E+01 2u: 1.17E-01 ir: 3.99E-15 iu: 1.17E-01 rsn:   0
#   2 2r: 1.49E-17 2x: 3.77E+01 2u: 7.39E-03 ir: 1.47E-17 iu: 7.39E-03 rsn:   0
#   3 2r: 2.19E-19 2x: 3.77E+01 2u: 2.74E-05 ir: 2.11E-19 iu: 2.74E-05 rsn:   0
#   4 2r: 2.19E-19 2x: 3.77E+01 2u: 3.76E-10 ir: 2.11E-19 iu: 3.76E-10 rsn: stol
#
#  Step    201 Time=  1.00000E+01 Dt=  4.58333E-02 [d] conv_reason: 4
#   newton =   4 [     667] linear =     4 [       667] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations = 4 / 4
#   --> SNES Residual: 0.218836E-18 0.218836E-18 0.210984E-18
#   --> max change:  dcmx=   2.4908E-13  dc/dt=   6.2900E-17 [mol/s]
#
#
# PMCSubsurfaceTransport
#  Total Time: 1.8601E-02 seconds
#
#  TRAN TS SNES steps = 201  newton = 667  linear = 667  cuts = 0
#  TRAN TS SNES Wasted Linear Iterations = 0
#  TRAN TS SNES Wasted Newton Iterations = 0
#  TRAN TS SNES time = 0.0 seconds
#
#  Wall Clock Time:  2.2973E-02 [sec]   3.8288E-04 [min]   6.3814E-06 [hr]
