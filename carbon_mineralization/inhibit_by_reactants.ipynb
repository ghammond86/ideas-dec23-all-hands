# %%
import os
import sys
sys.path.append('/scratch/ideas-dec23-all-hands/.python')
from run import run_pflotran
from plot import plot_results
os.chdir('/scratch/ideas-dec23-all-hands/carbon_mineralization')

# %%
prefix = 'inhibit_by_reactants'

# %%
run_pflotran(prefix)
# Out:
#   1 2r: 1.10E-18 2x: 3.50E+01 2u: 9.06E-05 ir: 7.85E-19 iu: 9.06E-05 rsn:   0
#   2 2r: 6.54E-20 2x: 3.50E+01 2u: 3.35E-08 ir: 4.33E-20 iu: 3.35E-08 rsn: stol
#
#  Step    218 Time=  9.97546E+00 Dt=  5.00000E-02 [d] conv_reason: 4
#   newton =   2 [    1180] linear =     2 [      1180] cuts =  0 [  10]
#   --> SNES Linear/Non-Linear Iterations = 2 / 2
#   --> SNES Residual: 0.654329E-19 0.654329E-19 0.433425E-19
#   --> max change:  dcmx=   9.0482E-15  dc/dt=   2.0945E-18 [mol/s]
#
# == REACTIVE TRANSPORT ==========================================================
#   0 2r: 3.48E-15 2x: 0.00E+00 2u: 0.00E+00 ir: 2.09E-15 iu: 0.00E+00 rsn:   0
#   1 2r: 3.39E-19 2x: 3.50E+01 2u: 4.41E-05 ir: 2.02E-19 iu: 4.41E-05 rsn:   0
#   2 2r: 2.05E-19 2x: 3.50E+01 2u: 4.27E-09 ir: 2.04E-19 iu: 4.27E-09 rsn: stol
#
#  Step    219 Time=  1.00000E+01 Dt=  2.45443E-02 [d] conv_reason: 4
#   newton =   2 [    1182] linear =     2 [      1182] cuts =  0 [  10]
#   --> SNES Linear/Non-Linear Iterations = 2 / 2
#   --> SNES Residual: 0.204912E-18 0.204912E-18 0.203958E-18
#   --> max change:  dcmx=   4.4036E-15  dc/dt=   2.0766E-18 [mol/s]
#
#
# PMCSubsurfaceTransport
#  Total Time: 2.7830E-02 seconds
#
#  TRAN TS SNES steps = 219  newton = 1182  linear = 1182  cuts = 10
#  TRAN TS SNES Wasted Linear Iterations = 500
#  TRAN TS SNES Wasted Newton Iterations = 500
#  TRAN TS SNES time = 0.0 seconds
#
#  Wall Clock Time:  3.2618E-02 [sec]   5.4363E-04 [min]   9.0605E-06 [hr]
