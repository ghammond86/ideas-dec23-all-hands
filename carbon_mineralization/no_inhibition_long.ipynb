# %%
import os
import sys
sys.path.append('/scratch/ideas-dec23-all-hands/.python')
from run import run_pflotran
from plot import plot_results
os.chdir('/scratch/ideas-dec23-all-hands/carbon_mineralization')

# %%
prefix = 'no_inhibition_long'

# %%
run_pflotran(prefix)
# Out:
# == REACTIVE TRANSPORT ==========================================================
#   0 2r: 0.00E+00 2x: 0.00E+00 2u: 0.00E+00 ir: 1.59-202 iu: 0.00E+00 rsn:   0
#   1 2r: 0.00E+00 2x: 4.62E+02 2u: 1.26E-01 ir: 1.40-202 iu: 1.26E-01 rsn: atol
#
#  Step   3600 Time=  1.79954E+02 Dt=  5.00000E-02 [d] conv_reason: 2
#   newton =   1 [    5956] linear =     1 [      5956] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations = 1 / 1
#   --> SNES Residual: 0.000000E+00 0.000000E+00 0.140035-201
#   --> max change:  dcmx=   5.6502-202  dc/dt=   1.3079-205 [mol/s]
#
# == REACTIVE TRANSPORT ==========================================================
#   0 2r: 0.00E+00 2x: 0.00E+00 2u: 0.00E+00 ir: 1.40-202 iu: 0.00E+00 rsn:   0
#   1 2r: 0.00E+00 2x: 4.62E+02 2u: 1.17E-01 ir: 1.25-202 iu: 1.17E-01 rsn: atol
#
#  Step   3601 Time=  1.80000E+02 Dt=  4.58333E-02 [d] conv_reason: 2
#   newton =   1 [    5957] linear =     1 [      5957] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations = 1 / 1
#   --> SNES Residual: 0.000000E+00 0.000000E+00 0.124586-201
#   --> max change:  dcmx=   4.6349-202  dc/dt=   1.1704-205 [mol/s]
#
#
# PMCSubsurfaceTransport
#  Total Time: 2.1385E-01 seconds
#
#  TRAN TS SNES steps = 3601  newton = 5957  linear = 5957  cuts = 0
#  TRAN TS SNES Wasted Linear Iterations = 0
#  TRAN TS SNES Wasted Newton Iterations = 0
#  TRAN TS SNES time = 0.1 seconds
#
#  Wall Clock Time:  2.8387E-01 [sec]   4.7312E-03 [min]   7.8853E-05 [hr]
