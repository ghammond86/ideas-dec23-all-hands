# %%
import os
import sys
sys.path.append('/scratch/ideas-dec23-all-hands/.python')
from run import run_pflotran
from plot import plot_results
os.chdir('/scratch/ideas-dec23-all-hands/carbon_mineralization')

# %%
prefix = 'inhibit_by_potential'

# %%
run_pflotran(prefix)
# Out:
#   4 2r: 1.42E-19 2x: 6.12E+01 2u: 2.32E-07 ir: 1.38E-19 iu: 2.32E-07 rsn: rtol
#
#  Step    201 Time=  9.97917E+00 Dt=  5.00000E-02 [d] conv_reason: 3
#   newton =   4 [     679] linear =     4 [       679] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations = 4 / 4
#   --> SNES Residual: 0.141526E-18 0.141526E-18 0.138356E-18
#   --> max change:  dcmx=   6.4800E-08  dc/dt=   1.5000E-11 [mol/s]
#
# == REACTIVE TRANSPORT ==========================================================
#   0 2r: 2.31E-08 2x: 0.00E+00 2u: 0.00E+00 ir: 1.50E-08 iu: 0.00E+00 rsn:   0
#   1 2r: 6.68E-10 2x: 6.12E+01 2u: 1.21E-01 ir: 6.53E-10 iu: 1.21E-01 rsn:   0
#   2 2r: 2.65E-12 2x: 6.12E+01 2u: 7.95E-03 ir: 2.59E-12 iu: 7.95E-03 rsn:   0
#   3 2r: 4.21E-17 2x: 6.12E+01 2u: 3.18E-05 ir: 4.12E-17 iu: 3.18E-05 rsn: rtol
#
#  Step    202 Time=  1.00000E+01 Dt=  2.08333E-02 [d] conv_reason: 3
#   newton =   3 [     682] linear =     3 [       682] cuts =  0 [   0]
#   --> SNES Linear/Non-Linear Iterations = 3 / 3
#   --> SNES Residual: 0.420945E-16 0.420945E-16 0.411535E-16
#   --> max change:  dcmx=   2.3733E-08  dc/dt=   1.3185E-11 [mol/s]
#
#
# PMCSubsurfaceTransport
#  Total Time: 1.8860E-02 seconds
#
#  TRAN TS SNES steps = 202  newton = 682  linear = 682  cuts = 0
#  TRAN TS SNES Wasted Linear Iterations = 0
#  TRAN TS SNES Wasted Newton Iterations = 0
#  TRAN TS SNES time = 0.0 seconds
#
#  Wall Clock Time:  2.3358E-02 [sec]   3.8930E-04 [min]   6.4883E-06 [hr]
