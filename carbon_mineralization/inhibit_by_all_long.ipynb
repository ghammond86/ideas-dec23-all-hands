# %%
import os
import sys
sys.path.append('/scratch/ideas-dec23-all-hands/.python')
from run import run_pflotran
from plot import plot_results
os.chdir('/scratch/ideas-dec23-all-hands/carbon_mineralization')

# %%
prefix = 'inhibit_by_all_long'

# %%
run_pflotran(prefix)
# Out:
#  Step    220 Time=  9.97065E+00 Dt=  5.00000E-02 [d] conv_reason: 3
#   newton =   4 [    1322] linear =     4 [      1322] cuts =  0 [  12]
#   --> SNES Linear/Non-Linear Iterations = 4 / 4
#   --> SNES Residual: 0.565836E-19 0.565836E-19 0.465504E-19
#   --> max change:  dcmx=   7.2869E-08  dc/dt=   1.6868E-11 [mol/s]
#
# == REACTIVE TRANSPORT ==========================================================
#   0 2r: 2.59E-08 2x: 0.00E+00 2u: 0.00E+00 ir: 1.68E-08 iu: 0.00E+00 rsn:   0
#   1 2r: 1.01E-09 2x: 3.47E+01 2u: 1.63E-01 ir: 9.73E-10 iu: 1.63E-01 rsn:   0
#   2 2r: 7.42E-12 2x: 3.47E+01 2u: 1.47E-02 ir: 7.13E-12 iu: 1.47E-02 rsn:   0
#   3 2r: 4.07E-16 2x: 3.47E+01 2u: 1.10E-04 ir: 3.91E-16 iu: 1.10E-04 rsn:   0
#   4 2r: 1.12E-19 2x: 3.47E+01 2u: 6.01E-09 ir: 8.57E-20 iu: 6.01E-09 rsn: rtol
#
#  Step    221 Time=  1.00000E+01 Dt=  2.93538E-02 [d] conv_reason: 3
#   newton =   4 [    1326] linear =     4 [      1326] cuts =  0 [  12]
# ...
